# %% [markdown]
# ## This is an example notebook running backtest using bitfinex info
#
# The follows the [tutorial](https://enigma.co/catalyst/beginner-tutorial.html#running-algorithms) here.

# %%
# %load_ext catalyst

# %%
# !catalyst ingest-exchange -x bitfinex -i btc_usd
# Out:
# Trying to ingest exchange bundle bitfinex...
#     [====================================]  Ingesting daily price data on bitfinex:  100%

# %%
# %%catalyst --start 2018-1-1 --end 2018-6-28 --capital-base 100000 -x bitfinex -c usd
#
# from catalyst.api import order, record, symbol
#
# def initialize(context):
#     context.asset = symbol('btc_usd')
#
#
# def handle_data(context, data):
#     order(context.asset, 1)
#     record(btc = data.current(context.asset, 'price'))
# Out:
# Running in backtesting mode.
# [2018-07-24 22:44:48.952942] WARNING: run_algo: Catalyst is currently in ALPHA. It is going through rapid development and it is subject to errors. Please use carefully. We encourage you to report any issue on GitHub: https://github.com/enigmampc/catalyst/issues
# [2018-07-24 22:44:48.954123] INFO: run_algo: Catalyst version 0.5.18
# [2018-07-24 22:44:51.959625] INFO: run_algo: running algo in backtest mode
# [2018-07-24 22:44:51.969221] INFO: exchange_algorithm: initialized trading algorithm in backtest mode
# [2018-07-24 22:44:53.298509] INFO: Performance: Simulated 179 trading days out of 179.
# [2018-07-24 22:44:53.299369] INFO: Performance: first open: 2018-01-01 00:00:00+00:00
# [2018-07-24 22:44:53.300053] INFO: Performance: last close: 2018-06-28 23:59:00+00:00
#                            algo_volatility  algorithm_period_return alpha  \
# 2018-01-01 23:59:00+00:00              NaN                 0.000000  None
# ...
